# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
x = np.array([0, 1, 3, 4, 5, 6, 7, 8, 9, 10])
y = np.array([0, 1, 3, 4, 5, 6, 7, 8, 9, 10])
plt.plot(x, y)

plt.xlim([0, max(x)])
plt.ylim([0, max(y)])
plt.xlabel("Ort x [m]")
plt.ylabel("Zeit [s]")
plt.show()
