# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
x = np.array([0,10])
y = np.array([0,20])
plt.plot(x, y)

plt.xlim([0, max(x)])
plt.ylim([0, max(y)])
plt.title("xt-Diagramm")
plt.xlabel("Ort x [m]")
plt.ylabel("Zeit [s]")
plt.show()
plt.savefig('test.png')
